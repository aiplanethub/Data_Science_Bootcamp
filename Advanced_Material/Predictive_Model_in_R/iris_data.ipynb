# %% [markdown]
# **Note:** In this notebook we have used different approach than the approach used by **Mr Ramanathan R** in R programming language.
#
# His code can be found here: https://github.com/dphi-official/iris_data_exploration/blob/master/DataComprehension.R

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings 
warnings.filterwarnings("ignore")

# %%
# Load Data
iris = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/iris.csv")

# %%
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
# Renaming columns
iris.rename(columns={'sepal.length': 'sepal_length', 'sepal.width': 'sepal_width', 'petal.length': 'petal_length', 'petal.width': 'petal_width'}, inplace=True)

# %%
# concise summary
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# checking different classes of iris
iris.variety.value_counts()
# Out:
# Versicolor    50
# Setosa        50
# Virginica     50
# Name: variety, dtype: int64

# %%
sns.countplot(iris.variety)

# %%
sns.distplot(iris.sepal_length)

# %%
sns.distplot(iris.sepal_width)

# %%
# Lets check given Sepal.Length, can we predict Petal.Length
# Lets investigate scatter chart first
sns.scatterplot(iris.sepal_length, iris.petal_length)

# %%
# pairplot
sns.pairplot(iris)

# %%
# Separating X and y
X = iris[['petal_length']]
y = iris['sepal_length']

# %%
# Splitting data into train and test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
print("Train accuracy: ", lr.score(X_train, y_train))
print("Test accuracy: ", lr.score(X_test, y_test))
# Out:
# Train accuracy:  0.7513962004961177
# Test accuracy:  0.7674291077448563
